# %%
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt

# Load data
results = pd.read_csv("/home/nnieto/Nico/Harmonization/QC/output/sex_classification/results_single_site_SALD_eNKI_CamCAN_all_sampling_Q.csv")
metric_to_plot = "AUC"

results_test = results[results["Model"] == "None Test"]

plt.figure(figsize=(15, 10))
sbn.boxplot(data=results_test, x="Site", y=metric_to_plot, hue="QC_Sampling")
plt.grid()
plt.title("AUC for single site classification")
# Out:
# Text(0.5, 1.0, 'AUC for single site classification')

# %%
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt

# Load data
results = pd.read_csv("/home/nnieto/Nico/Harmonization/QC/output/sex_classification/results_pooled_data_site_SALD_eNKI_CamCAN_all_sampling_Q.csv")
metric_to_plot = "AUC"

results_test = results[results["Model"] == "Pooled data Test"]

plt.figure(figsize=(15, 10))
sbn.boxplot(data=results_test, x="Site", y=metric_to_plot, hue="QC_Sampling")
plt.grid()
plt.title("AUC for Pooled data classification")
# Out:
# Text(0.5, 1.0, 'AUC for Pooled data classification')

# %%
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt

# Load data
results = pd.read_csv("/home/nnieto/Nico/Harmonization/QC/output/sex_classification/results_unconf_pooled_data_site_SALD_eNKI_CamCAN_all_sampling_Q.csv")
metric_to_plot = "AUC"

results_test = results[results["Model"] == "Pooled data Test"]

plt.figure(figsize=(15, 10))
sbn.boxplot(data=results_test, x="Site", y=metric_to_plot, hue="QC_Sampling")
plt.grid()
plt.title("AUC for Pooled data classification")
# Out:
# Text(0.5, 1.0, 'AUC for Pooled data classification')

# %%
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt

# Load data
results = pd.read_csv("/home/nnieto/Nico/Harmonization/QC/output/sex_classification/results_5_bins_unconf_pooled_data_site_SALD_eNKI_CamCAN_all_sampling_Q.csv")
metric_to_plot = "AUC"

results_test = results[results["Model"] == "Pooled data Test"]

plt.figure(figsize=(15, 10))
sbn.boxplot(data=results_test, x="Site", y=metric_to_plot, hue="QC_Sampling")
plt.grid()
plt.title("AUC for Pooled data classification - Confound remove")
plt.show()

# %%
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt

# Load data
results = pd.read_csv("/home/nnieto/Nico/Harmonization/QC/output/sex_classification/results_10_bins_unconf_pooled_data_site_SALD_eNKI_CamCAN_all_sampling_Q.csv")
metric_to_plot = "AUC"

results_test = results[results["Model"] == "Pooled data Test"]

plt.figure(figsize=(15, 10))
sbn.boxplot(data=results_test, x="Site", y=metric_to_plot, hue="QC_Sampling")
plt.grid()
plt.title("AUC for Pooled data classification - Confound remove")
plt.show()

# %%
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt

# Load data
results = pd.read_csv("/home/nnieto/Nico/Harmonization/QC/output/sex_classification/results_pooled_data_site_SALD_eNKI_CamCAN_all_sampling_Q.csv")
metric_to_plot = "AUC"

results_test = results[results["Model"] == "Pooled data Test"]


# Load data
results = pd.read_csv("/home/nnieto/Nico/Harmonization/QC/output/sex_classification/results_40_bins_unconf_pooled_data_site_SALD_eNKI_CamCAN_all_sampling_Q.csv")
metric_to_plot = "AUC"

results_test_cf = results[results["Model"] == "Pooled data Test"]
results_test_cf["QC_Sampling"] = results["QC_Sampling"] + "_confound_removed"

hue_order = ['low_Q_confound_removed','low_Q' , 'high_Q_confound_removed', 'high_Q',
       'random_Q_confound_removed',  'random_Q']

results_test = pd.concat([results_test,results_test_cf])
plt.figure(figsize=(15, 10))
sbn.boxplot(data=results_test, x="Site", y=metric_to_plot, hue="QC_Sampling", hue_order=hue_order)
plt.grid()
plt.title("AUC for Pooled data classification")
# Out:
# /tmp/ipykernel_9428/3775149249.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_test_cf["QC_Sampling"] = results["QC_Sampling"] + "_confound_removed"
# Text(0.5, 1.0, 'AUC for Pooled data classification')

# %%
results_test["QC_Sampling"].unique()
# Out:
# array(['low_Q', 'high_Q', 'random_Q', 'low_Qconfound_removed',
#        'high_Qconfound_removed', 'random_Qconfound_removed'], dtype=object)

# %% [markdown]
# # After bug

# %%
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt

# Load data
results = pd.read_csv("/home/nnieto/Nico/Harmonization/QC/output/sex_classification/results_unconfound_single_site_SALD_eNKI_CamCAN_all_sampling_Q.csv")
metric_to_plot = "AUC"

results_test = results[results["Model"] == "None Test"]

plt.figure(figsize=(15, 10))
sbn.boxplot(data=results_test, x="Site", y=metric_to_plot, hue="QC_Sampling")
plt.grid()
plt.title("AUC for single site classification")
# Out:
# Text(0.5, 1.0, 'AUC for single site classification')

# %%
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt

# Load data
results = pd.read_csv("/home/nnieto/Nico/Harmonization/QC/output/sex_classification/results_10_bins_unconf_pooled_data_site_SALD_eNKI_CamCAN_all_sampling_Q.csv")
metric_to_plot = "AUC"

results_test = results[results["Model"] == "Pooled data Test"]

# plt.figure(figsize=(15, 10))
# sbn.boxplot(data=results_test, x="Site", y=metric_to_plot, hue="QC_Sampling")
# plt.grid()
# plt.title("AUC for Voxel Pooled data classification - Confound remove")
# plt.show()

for qc in results_test["QC_Sampling"].unique():
    print(qc)
    d = results_test[results_test["QC_Sampling"] == qc]
    for site in results_test["Site"].unique():
        s =  d[d["Site"] ==site]
        print(site)
        print(s[metric_to_plot].mean())
        print(s[metric_to_plot].std())
# Out:
# low_Q
# SALD
# 0.6497971201231799
# 0.08913674809599954
# eNKI
# 0.8073006762682486
# 0.06902927677241803
# CamCAN
# 0.7831360701665682
# 0.06627635878601633
# high_Q
# SALD
# 0.7395136181809312
# 0.07394057548830277
# eNKI
# 0.8365561573576291
# 0.06300358244044994
# CamCAN
# 0.7460215733516956
# 0.07028247359971436
# random_Q
# SALD
# 0.707205678072377
# 0.08549567568111516
# eNKI
# 0.8351261992006165
# 0.043664894500585666
# CamCAN
# 0.813751442708905
# 0.049375854385725705

# %%
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt

# Load data
results = pd.read_csv("/home/nnieto/Nico/Harmonization/QC/output/sex_classification/results_3_bins_unconf_pooled_data_site_SALD_eNKI_CamCAN_all_sampling_Q.csv")
metric_to_plot = "AUC"

results_test = results[results["Model"] == "Pooled data Test"]

plt.figure(figsize=(15, 10))
sbn.boxplot(data=results_test, x="QC_Sampling", y=metric_to_plot, hue="QC_Sampling")
plt.grid()
plt.title("AUC for Voxel Pooled data classification - Confound remove - 3 age bins")
plt.show()
for qc in results_test["QC_Sampling"].unique():
    print(qc)
    d = results_test[results_test["QC_Sampling"] == qc]
    print(d[metric_to_plot].mean())
    print(d[metric_to_plot].std())
# Out:
# low_Q
# 0.7728400127896647
# 0.07048299368587974
# high_Q
# 0.7800788293886202
# 0.07412429304146279
# random_Q
# 0.8038643709797593
# 0.0562118127712735

# %%
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt

results_random = pd.read_csv("/home/nnieto/Nico/Harmonization/QC/output/sex_classification/results_10_bins_random_20_repetitions_N_balanced_unconf_pooled_data_site_SALD_eNKI_CamCAN_all_sampling_Q.csv")
results_random.drop(columns=["Repeated"])
# Load data
results = pd.read_csv("/home/nnieto/Nico/Harmonization/QC/output/sex_classification/results_10_bins_balanced_N_unconf_pooled_data_site_SALD_eNKI_CamCAN_all_sampling_Q.csv")

results = results[results["QC_Sampling"] != "random_Q"]

results = pd.concat([results, results_random])

metric_to_plot = "AUC"

results_test = results[results["Model"] == "Pooled data Test"]

plt.figure(figsize=(15, 10))
sbn.boxplot(data=results_test, x="Site", y=metric_to_plot, hue="QC_Sampling")
plt.grid()
plt.title("AUC for Voxel Pooled data classification - Confound remove - 10 age bins")
plt.show()
for qc in results_test["QC_Sampling"].unique():
    print(qc)
    d = results_test[results_test["QC_Sampling"] == qc]
    for site in results_test["Site"].unique():
        s =  d[d["Site"] ==site]
        print(site)
        print(s[metric_to_plot].mean())
        print(s[metric_to_plot].std())
# Out:
# low_Q
# SALD
# 0.6557660997075472
# 0.08676901642682637
# eNKI
# 0.7893311012857839
# 0.08543490205595632
# CamCAN
# 0.7482793203495776
# 0.07529868699967061
# high_Q
# SALD
# 0.7085370470084491
# 0.07358817407936466
# eNKI
# 0.7885118621266359
# 0.07251645712829694
# CamCAN
# 0.7559359705826136
# 0.07495951197528444
# ['random_Q']
# SALD
# 0.6583550383198855
# 0.0820147936669941
# eNKI
# 0.7941076870360793
# 0.07259723961599025
# CamCAN
# 0.75810018173324
# 0.07954418282605143

# %% [markdown]
# # FINAL PLOTS

# %% [markdown]
# ## 10 bins

# %%
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt
SMALL_SIZE = 20
MEDIUM_SIZE = 25
BIGGER_SIZE = 30
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title



metric_to_plot = "AUC"

results_random = pd.read_csv("/home/nnieto/Nico/Harmonization/QC/output/sex_classification/results_10_bins_random_20_repetitions_unconf_pooled_data_site_SALD_eNKI_CamCAN_all_sampling_Q.csv")
results_random.drop(columns=["Repeated"])
results_random["QC_Sampling"] = "random_Q"
# Load data pooled
results = pd.read_csv("/home/nnieto/Nico/Harmonization/QC/output/sex_classification/results_10_bins_unconf_pooled_data_site_SALD_eNKI_CamCAN_all_sampling_Q.csv")
metric_to_plot = "AUC"
results = results[results["QC_Sampling"] != "random_Q"]
results = pd.concat([results,results_random])

results_pooled = results[results["Model"] == "Pooled data Test"]

results_pooled["Site"] = "Pooled"

save_dir = "/home/nnieto/Nico/Harmonization/QC/output/final/single_site/"
# Load data
results = pd.read_csv(save_dir+"results_unconfound_10bins_single_site_SALD_eNKI_CamCAN_high_low_sampling_Q.csv")
results = results[results["Model"] == "None Test"]

results_random = pd.read_csv(save_dir + "/results_single_site_10_bins_random_20_repetitions_unconf_data_site_SALD_eNKI_CamCAN_high_low_sampling_Q.csv")
results_random.drop(columns=["Repeated"])
results_random = results_random[results_random["Model"] == "Pooled data Test"]
results_random["QC_Sampling"] = "random_Q"
results_random.drop(columns=["Model"])
results.drop(columns=["Model"])

results_test = pd.concat([results, results_random, results_pooled])

order = ["low_Q","random_Q","high_Q"]
plt.figure(figsize=(15, 10))
sbn.boxplot(data=results_test, x="Site",
            y=metric_to_plot, hue="QC_Sampling",
            hue_order=order, palette=sbn.color_palette("tab10")
            )
plt.grid()
plt.xlabel("Training data")

plt.ylabel("Test AUC")
# Out:
# /tmp/ipykernel_29520/913339673.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_pooled["Site"] = "Pooled"
# /tmp/ipykernel_29520/913339673.py:48: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   sbn.boxplot(data=results_test, x="Site",
# Text(0, 0.5, 'Test AUC')

# %%
for qc in results_test["QC_Sampling"].unique():
    print(qc)
    d = results_test[results_test["QC_Sampling"] == qc]
    for site in results_test["Site"].unique():
        s =  d[d["Site"] ==site]
        print(site)
        print(s[metric_to_plot].mean())
        print(s[metric_to_plot].std())
# Out:
# low_Q
# SALD
# 0.6437999999999999
# 0.06773154730256796
# eNKI
# 0.7929591836734694
# 0.06544552411550192
# CamCAN
# 0.7509183673469387
# 0.04949012465701886
# Pooled
# 0.7467446221859988
# 0.10202184071492354
# high_Q
# SALD
# 0.7121
# 0.07862980245004646
# eNKI
# 0.7761224489795918
# 0.057882638070651624
# CamCAN
# 0.7433673469387755
# 0.09421163357907664
# Pooled
# 0.7740304496300855
# 0.08155293356799904
# random_Q
# SALD
# 0.6408349999999999
# 0.08962158966268861
# eNKI
# 0.7718265306122449
# 0.0662927940583053
# CamCAN
# 0.7417704081632653
# 0.06875370031742079
# Pooled
# 0.7515343294591329
# 0.09448492516716793

# %% [markdown]
# ## 3 bins

# %%
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt
SMALL_SIZE = 20
MEDIUM_SIZE = 25
BIGGER_SIZE = 30
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title



metric_to_plot = "AUC"

results_random = pd.read_csv("/home/nnieto/Nico/Harmonization/QC/output/sex_classification/results_3_bins_random_20_repetitions_N_balanced_unconf_pooled_data_site_SALD_eNKI_CamCAN_all_sampling_Q.csv")
results_random.drop(columns=["Repeated"])
results_random["QC_Sampling"] = "random_Q"
# Load data pooled
results = pd.read_csv("/home/nnieto/Nico/Harmonization/QC/output/sex_classification/results_3_bins_unconf_pooled_data_site_SALD_eNKI_CamCAN_all_sampling_Q.csv")
metric_to_plot = "AUC"
results = results[results["QC_Sampling"] != "random_Q"]
results = pd.concat([results,results_random])

results_pooled = results[results["Model"] == "Pooled data Test"]

results_pooled["Site"] = "Pooled"

save_dir = "/home/nnieto/Nico/Harmonization/QC/output/final/single_site/"
# Load data
results = pd.read_csv(save_dir+"results_unconfound_3bins_single_site_SALD_eNKI_CamCAN_high_low_sampling_Q.csv")
results = results[results["Model"] == "None Test"]

results_random = pd.read_csv(save_dir + "/results_single_site_3_bins_random_20_repetitions_unconf_data_site_SALD_eNKI_CamCAN_high_low_sampling_Q.csv")
results_random.drop(columns=["Repeated"])
results_random = results_random[results_random["Model"] == "Pooled data Test"]
results_random["QC_Sampling"] = "random_Q"
results_random.drop(columns=["Model"])
results.drop(columns=["Model"])

results_test = pd.concat([results, results_random, results_pooled])

order = ["low_Q","random_Q","high_Q"]
plt.figure(figsize=(15, 10))
sbn.boxplot(data=results_test, x="Site",
            y=metric_to_plot, hue="QC_Sampling", dodge=True,
            hue_order=order, palette=sbn.color_palette("tab10")
            )
plt.grid()
plt.xlabel("Training data")

plt.ylabel("Test AUC")
# Out:
# /tmp/ipykernel_29520/121159813.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_pooled["Site"] = "Pooled"
# /tmp/ipykernel_29520/121159813.py:48: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   sbn.boxplot(data=results_test, x="Site",
# Text(0, 0.5, 'Test AUC')

# %%
for qc in results_test["QC_Sampling"].unique():
    print(qc)
    d = results_test[results_test["QC_Sampling"] == qc]
    for site in results_test["Site"].unique():
        s =  d[d["Site"] ==site]
        print(site)
        print(s[metric_to_plot].mean())
        print(s[metric_to_plot].std())
# Out:
# low_Q
# SALD
# 0.6857722554262348
# 0.055565945618626524
# eNKI
# 0.7939251590306214
# 0.050355545084304745
# CamCAN
# 0.7232917409387999
# 0.06741562747447362
# Pooled
# 0.7728400127896647
# 0.07048299368587974
# high_Q
# SALD
# 0.6862703156128761
# 0.06853783680974473
# eNKI
# 0.770120786010456
# 0.05717466220631055
# CamCAN
# 0.7092043428941825
# 0.06739916243741266
# Pooled
# 0.7800788293886202
# 0.07412429304146279
# random_Q
# SALD
# 0.6536331131383035
# 0.060583041807834165
# eNKI
# 0.7761731952921784
# 0.04828468154012687
# CamCAN
# 0.7075795387025333
# 0.06667119176094696
# Pooled
# 0.7705367172801346
# 0.07317635049394197

# %% [markdown]
# # merged plot

# %%
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt
SMALL_SIZE = 20
MEDIUM_SIZE = 25
BIGGER_SIZE = 30
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title



metric_to_plot = "AUC"

results_random = pd.read_csv("/home/nnieto/Nico/Harmonization/QC/output/sex_classification/results_10_bins_random_20_repetitions_unconf_pooled_data_site_SALD_eNKI_CamCAN_all_sampling_Q.csv")
results_random.drop(columns=["Repeated"])
results_random["QC_Sampling"] = "random_Q"
# Load data pooled
results = pd.read_csv("/home/nnieto/Nico/Harmonization/QC/output/sex_classification/results_10_bins_unconf_pooled_data_site_SALD_eNKI_CamCAN_all_sampling_Q.csv")
metric_to_plot = "AUC"
results = results[results["QC_Sampling"] != "random_Q"]
results = pd.concat([results,results_random])

results_pooled = results[results["Model"] == "Pooled data Test"]

results_pooled["Site"] = "Pooled"

save_dir = "/home/nnieto/Nico/Harmonization/QC/output/final/single_site/"
# Load data
results = pd.read_csv(save_dir+"results_unconfound_10bins_single_site_SALD_eNKI_CamCAN_high_low_sampling_Q.csv")
results = results[results["Model"] == "None Test"]

results_random = pd.read_csv(save_dir + "/results_single_site_10_bins_random_20_repetitions_unconf_data_site_SALD_eNKI_CamCAN_high_low_sampling_Q.csv")
results_random.drop(columns=["Repeated"])
results_random = results_random[results_random["Model"] == "Pooled data Test"]
results_random["QC_Sampling"] = "random_Q"
results_random.drop(columns=["Model"])
results.drop(columns=["Model"])

results_test = pd.concat([results, results_random, results_pooled])
results_test.QC_Sampling.replace({"low_Q":"low Q","random_Q":"random Q","high_Q":"high Q"}, inplace=True)
results_test.rename(columns={"QC_Sampling": "Q Sampling"}, inplace=True)
order = ["low Q","random Q","high Q"]
plt.figure(figsize=(17, 17))
plt.subplot(2, 1, 1)

sbn.boxenplot(data=results_test, x="Site",
            y=metric_to_plot, hue="Q Sampling",
            hue_order=order, palette=sbn.color_palette("tab10")
            )
plt.grid()
plt.ylim([0.35,1])
plt.xlabel("Training data")
plt.title("A", loc="left")

plt.ylabel("Test AUC")


metric_to_plot = "AUC"

results_random = pd.read_csv("/home/nnieto/Nico/Harmonization/QC/output/sex_classification/results_3_bins_random_20_repetitions_N_balanced_unconf_pooled_data_site_SALD_eNKI_CamCAN_all_sampling_Q.csv")
results_random.drop(columns=["Repeated"])
results_random["QC_Sampling"] = "random_Q"

# Load data pooled
results = pd.read_csv("/home/nnieto/Nico/Harmonization/QC/output/sex_classification/results_3_bins_unconf_pooled_data_site_SALD_eNKI_CamCAN_all_sampling_Q.csv")
metric_to_plot = "AUC"
results = results[results["QC_Sampling"] != "random_Q"]

results = pd.concat([results,results_random])

results_pooled = results[results["Model"] == "Pooled data Test"]

results_pooled["Site"] = "Pooled"

save_dir = "/home/nnieto/Nico/Harmonization/QC/output/final/single_site/"
# Load data
results = pd.read_csv(save_dir+"results_unconfound_3bins_single_site_SALD_eNKI_CamCAN_high_low_sampling_Q.csv")
results = results[results["Model"] == "None Test"]

results_random = pd.read_csv(save_dir + "/results_single_site_3_bins_random_20_repetitions_unconf_data_site_SALD_eNKI_CamCAN_high_low_sampling_Q.csv")
results_random.drop(columns=["Repeated"])
results_random = results_random[results_random["Model"] == "Pooled data Test"]
results_random["QC_Sampling"] = "random_Q"
results_random.drop(columns=["Model"])
results.drop(columns=["Model"])

results_test = pd.concat([results, results_random, results_pooled])
results_test.QC_Sampling.replace({"low_Q":"low Q","random_Q":"random Q","high_Q":"high Q"}, inplace=True)
results_test.rename(columns={"QC_Sampling": "Q Sampling"}, inplace=True)

order = ["low Q","random Q","high Q"]
plt.subplot(2, 1, 2)
sbn.boxenplot(data=results_test, x="Site",
            y=metric_to_plot, hue="Q Sampling", dodge=True,
            hue_order=order, palette=sbn.color_palette("tab10")
            )
plt.ylim([0.35,1])
plt.title("B", loc="left")

plt.grid()
plt.xlabel("Training data")

plt.ylabel("Test AUC")
# Out:
# /tmp/ipykernel_29520/1848967779.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_pooled["Site"] = "Pooled"
# /tmp/ipykernel_29520/1848967779.py:45: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# ...

# %%
# Out:
# low_Q
# SALD
# 0.6857722554262348
# 0.055565945618626524
# eNKI
# 0.7939251590306214
# 0.050355545084304745
# CamCAN
# 0.7232917409387999
# 0.06741562747447362
# Pooled
# 0.7728400127896647
# 0.07048299368587974
# high_Q
# SALD
# 0.6862703156128761
# 0.06853783680974473
# eNKI
# 0.770120786010456
# 0.05717466220631055
# CamCAN
# 0.7092043428941825
# 0.06739916243741266
# Pooled
# 0.7800788293886202
# 0.07412429304146279
# random_Q
# SALD
# 0.6536331131383035
# 0.060583041807834165
# eNKI
# 0.7761731952921784
# 0.04828468154012687
# CamCAN
# 0.7075795387025333
# 0.06667119176094696
# Pooled
# 0.7124619490443383
# 0.0774201744606603
